# %%
import os
import re
import nibabel as nib
import numpy as np
from itertools import combinations
from typing import List, Dict
import pandas as pd
from reidentification_utils import extract_Nyxus_features, NYXUS_ALL_FEATURES, NYXUS_SHAPE_FEATURES, NYXUS_TEXTURE_FEATURES, NYXUS_FIRSTORDER_FEATURES
image_dir = "/home/ubuntu/data/ADNI_dataset/BrainIAC_processed/images/"
features_dir = "/home/ubuntu/data/ADNI_dataset/Nyxus_features/"
info_csv = "/home/ubuntu/data/ADNI_dataset/BrainIAC_input_csv/brainiac_ADNI_info.csv"
output_dir = "./Nyxus_reidentification_analysis"

# %%
features = extract_Nyxus_features(
    features_dir=features_dir,
    features_group="All",
)

# %%
print(features.shape)
features.head()
# Out:
# (2154, 213)
#        3COV  3COVERED_IMAGE_INTENSITY_RANGE       3ENERGY  3ENTROPY  \
# 0  0.400906                             1.0  2.301380e+09  3.546647
# 1  0.358455                             1.0  9.898307e+10  3.697837
# 2  0.325405                             1.0  4.492078e+11  3.824521
# 3  0.352849                             1.0  5.818625e+11  3.916081
# 4  0.404911                             1.0  2.810147e+11  4.019599
#
#    3EXCESS_KURTOSIS  3HYPERFLATNESS  3HYPERSKEWNESS  3INTEGRATED_INTENSITY  \
# 0         -0.660348        7.840370       -3.151001             51160326.0
# 1         -0.729154        7.006858       -2.490378            329857389.0
# 2         -0.420261        9.707200       -3.898365            761772722.0
# 3         -0.709736        7.570138       -2.976383            782879249.0
# 4         -0.972615        5.346200       -2.159163            552893437.0
#
#    3INTERQUARTILE_RANGE  3KURTOSIS  ...  3GLRLM_RP_AVE  3GLRLM_GLV_AVE  \
# 0             24.021602   2.339652  ...       0.865729      124.656749
# 1            146.599836   2.270846  ...       0.889835      139.463468
# 2            246.606370   2.579739  ...       0.902472      183.674668
# 3            372.845157   2.290264  ...       0.903361      210.496278
# 4            291.346501   2.027385  ...       0.906923      240.180430
#
#    3GLRLM_RV_AVE  3GLRLM_RE_AVE  3GLRLM_LGLRE_AVE  3GLRLM_HGLRE_AVE  \
# 0      92.492988       6.107536          0.048823        739.917288
# 1      84.084943       6.171508          0.044354        956.798536
# 2      98.940859       6.252429          0.041877       1419.528106
# 3      85.783810       6.354939          0.043486       1445.349678
# 4     100.859065       6.411892          0.044676       1413.006059
#
#    3GLRLM_SRLGLE_AVE  3GLRLM_SRHGLE_AVE  3GLRLM_LRLGLE_AVE  3GLRLM_LRHGLE_AVE
# 0           0.006578         631.633038          97.373531        1626.862842
# 1           0.004150         835.263599          88.447246        1864.132667
# 2           0.002807        1257.316712         103.717678        2535.312711
# 3           0.002960        1272.909979          90.170565        2707.717574
# 4           0.003065        1255.283586         105.940932        2517.603266
#
# [5 rows x 213 columns]

# %%
feature_stats = features.describe().T
feature_stats['range'] = feature_stats['max'] - feature_stats['min']
feature_stats = feature_stats.sort_values('max', ascending=False)

# Display features with largest values
print("Features sorted by maximum value (largest first):")
print(feature_stats[['min', 'max', 'mean', 'std', 'range']].head(20))
# Out:
# Features sorted by maximum value (largest first):
#                                 min           max          mean           std  \
# 3ENERGY                1.371705e+09  7.422024e+12  2.735574e+11  3.595565e+11
# 3UNIFORMITY            3.971416e+09  6.061973e+10  1.528411e+10  7.464122e+09
# 3INTEGRATED_INTENSITY  3.796785e+07  3.226548e+09  5.199919e+08  2.633022e+08
# 3GLCM_CLUPROM          1.548014e+05  5.734879e+06  2.655908e+06  1.346736e+06
# 3GLCM_CLUPROM_AVE      1.518259e+05  5.638995e+06  2.607038e+06  1.322809e+06
# 3MESH_VOLUME           5.169236e+05  5.272790e+06  1.041551e+06  1.734010e+05
# 3VOLUME_CONVEXHULL     5.169236e+05  5.272790e+06  1.041551e+06  1.734010e+05
# 3GLSZM_LAHGLE          1.705860e+04  3.887262e+06  5.825651e+05  5.684904e+05
# 3GLCM_HOM2             9.854199e+05  2.620377e+06  2.043079e+06  1.978216e+05
# 3GLDZM_LDHGLE          3.558213e+05  2.378178e+06  1.405700e+06  4.309786e+05
# 3VOXEL_VOLUME          7.549042e+05  1.808473e+06  1.383341e+06  1.398047e+05
# 3GLRLM_RLN_AVE         4.814429e+05  1.155072e+06  8.760605e+05  9.453917e+04
# 3GLRLM_RLN             4.641681e+05  1.124392e+06  8.433009e+05  9.266720e+04
# 3NGLDM_DCNU            3.361966e+05  1.068288e+06  7.846750e+05  8.430960e+04
# 3NGLDM_GLNU            3.361966e+05  1.068288e+06  7.846750e+05  8.430960e+04
# 3VARIANCE              1.241638e+02  7.567804e+05  2.383128e+04  3.446618e+04
# 3VARIANCE_BIASED       1.241637e+02  7.567799e+05  2.383126e+04  3.446616e+04
# 3AREA                  6.100032e+04  7.207047e+05  8.821992e+04  1.605774e+04
# 3GLSZM_SZN             9.127974e+04  3.470400e+05  2.248129e+05  4.148007e+04
# 3GLDM_DN               1.061438e+05  2.891913e+05  1.952625e+05  2.663261e+04
#
#                               range
# 3ENERGY                7.420652e+12
# 3UNIFORMITY            5.664831e+10
# 3INTEGRATED_INTENSITY  3.188580e+09
# 3GLCM_CLUPROM          5.580078e+06
# 3GLCM_CLUPROM_AVE      5.487169e+06
# 3MESH_VOLUME           4.755867e+06
# 3VOLUME_CONVEXHULL     4.755867e+06
# 3GLSZM_LAHGLE          3.870204e+06
# 3GLCM_HOM2             1.634957e+06
# 3GLDZM_LDHGLE          2.022356e+06
# 3VOXEL_VOLUME          1.053569e+06
# 3GLRLM_RLN_AVE         6.736292e+05
# 3GLRLM_RLN             6.602236e+05
# 3NGLDM_DCNU            7.320914e+05
# 3NGLDM_GLNU            7.320914e+05
# 3VARIANCE              7.566562e+05
# 3VARIANCE_BIASED       7.566558e+05
# 3AREA                  6.597043e+05
# 3GLSZM_SZN             2.557603e+05
# 3GLDM_DN               1.830476e+05

# %%
def get_feature_type(col_name):
    if col_name in NYXUS_SHAPE_FEATURES:
        return 'Shape'
    elif col_name in NYXUS_TEXTURE_FEATURES:
        return 'Texture'
    elif col_name in NYXUS_FIRSTORDER_FEATURES:
        return 'Firstorder'

feature_stats['feature_type'] = feature_stats.index.map(get_feature_type)
print(feature_stats.groupby('feature_type')[['min', 'max', 'mean', 'std', 'range']].agg(['mean', 'min', 'max']))
# Out:
#                        min                                       max  \
#                       mean           min           max          mean
# feature_type
# Firstorder    1.494747e+08 -5.448179e+00  3.971416e+09  2.079409e+11
# Shape         1.321478e+05  5.845454e-04  7.549042e+05  9.339433e+05
# Texture      -7.294390e+05 -6.182294e+07  9.854199e+05 -1.098471e+05
#
#                                                   mean                \
#                        min           max          mean           min
# feature_type
# Firstorder   -2.123458e-01  7.422024e+12  8.037822e+09 -2.759119e+00
# Shape         3.961125e-02  5.272790e+06  2.539321e+05  3.015115e-02
# Texture      -2.214803e+07  5.734879e+06 -5.030676e+05 -4.815299e+07
#
#                                      std                          \
#                        max          mean       min           max
# feature_type
# Firstorder    2.735574e+11  1.020233e+10  0.000000  3.595565e+11
# Shape         1.383341e+06  3.590577e+04  0.003279  1.734010e+05
# Texture       2.655908e+06  8.472414e+04  0.000000  4.764281e+06
#
#                      range
#                       mean       min           max
# feature_type
# Firstorder    2.077914e+11  0.000000  7.420652e+12
# Shape         8.017955e+05  0.038329  4.755867e+06
# Texture       6.195919e+05  0.000000  3.967491e+07

# %%
from sklearn.preprocessing import StandardScaler
standard_features = StandardScaler().fit_transform(features)

# %%
feature_stats = standard_features.describe().T
feature_stats['range'] = feature_stats['max'] - feature_stats['min']
feature_stats = feature_stats.sort_values('max', ascending=False)

feature_stats['feature_type'] = feature_stats.index.map(get_feature_type)
print(feature_stats.groupby('feature_type')[['min', 'max', 'mean', 'std', 'range']].agg(['mean', 'min', 'max']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 feature_stats = standard_features.describe().T
#       2 feature_stats['range'] = feature_stats['max'] - feature_stats['min']
#       3 feature_stats = feature_stats.sort_values('max', ascending=False)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'
